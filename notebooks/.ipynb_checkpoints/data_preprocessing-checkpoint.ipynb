# %% [markdown]
# # Data Preprocessing
#
# In this notebook, I'll clean up the data we scraped with ``scrape.py`` so it can be fed into our CNN.

# %%
from skimage import color
from skimage import io
import numpy as np
import os
from PIL import Image

# %%
num_files = len(os.listdir('../data/raw'))
for i, file in enumerate(os.listdir('../data/raw')):
    if i == 2: break
    try:
        img = Image.open('../data/raw/{}'.format(file))
    except:
        raise FileNotFoundError()
    img = img.resize((256, 256))
    test = np.asarray(img)
    print(test)
#     img = Image.fromarray(np.divide(np.uint8(img), 255))
#     print(img)
#     img.show()
# Out:
# [[[248 236  92]
#   [247 235  88]
#   [250 237  95]
#   ...
#   [227 219  95]
#   [226 218  92]
#   [226 218  90]]
#
#  [[247 235  91]
#   [248 235  91]
#   [250 238  96]
#   ...
#   [227 218  95]
#   [225 217  93]
#   [226 218  93]]
#
#  [[249 238  95]
#   [249 239  98]
#   [249 240 101]
#   ...
#   [225 216  95]
#   [224 216  92]
#   [224 216  92]]
#
#  ...
#
#  [[213 171 147]
#   [215 171 146]
#   [215 171 146]
#   ...
#   [203 157 133]
#   [205 159 136]
#   [207 162 140]]
#
#  [[213 171 147]
#   [215 172 147]
#   [216 172 145]
#   ...
#   [202 156 131]
#   [204 158 134]
#   [206 160 137]]
#
#  [[213 171 147]
#   [215 172 147]
#   [216 172 146]
#   ...
#   [201 156 130]
#   [204 158 134]
#   [206 160 136]]]
# [[[251 246 240]
#   [251 248 241]
#   [251 248 241]
#   ...
#   [253 249 246]
#   [253 249 246]
#   [253 249 246]]
#
#  [[251 246 240]
#   [251 248 242]
#   [251 248 242]
#   ...
#   [252 250 246]
#   [252 250 246]
#   [253 250 246]]
#
#  [[251 247 241]
#   [251 248 241]
#   [251 248 241]
#   ...
#   [252 249 246]
#   [252 249 246]
#   [252 250 246]]
#
#  ...
#
#  [[250 246 237]
#   [250 246 237]
#   [250 246 237]
#   ...
#   [253 250 245]
#   [253 250 245]
#   [252 249 244]]
#
#  [[250 246 237]
#   [250 246 237]
#   [250 246 237]
#   ...
#   [253 250 245]
#   [253 250 245]
#   [253 250 245]]
#
#  [[250 246 237]
#   [250 246 237]
#   [250 246 237]
#   ...
#   [252 249 244]
#   [253 250 245]
#   [253 250 245]]]
